# %% [markdown]
# ## DeeepSense Project

# %%
## Import library
import tensorflow as tf
import numpy as np
import pandas as pd
import json

# %%
## Import natural language processing toolkit 
import re
import nltk
import string
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from replacers import RepeatReplacer
from replacers import RegexpReplacer

# %%
# Download data for NLP toolkit
nltk.download()

# %% [markdown]
# #### Loading data from JSON file

# %%
def loading_data(file_name):
    with open(file_name, 'r') as file:
        data = (json.loads(line) for i, line in enumerate(file.readlines()))
    return data

# %%
amazond_data = loading_data('user_dedup.json')

# %%
# Store data into DataFrame
pd.DataFrame([index for index in customer_reviews])
# Out:
#               asin   helpful  overall  \
# 0       B003UYU16G    [0, 0]      5.0
# 1       B005FYPK9C    [0, 0]      5.0
# 2       B000VEBG9Y    [0, 0]      3.0
# 3       B001EJMS6K    [0, 0]      4.0
# 4       B003XJCNVO    [0, 0]      4.0
# 5       B00G3KN9LI    [0, 0]      4.0
# 6       B000SAUVC4    [0, 0]      5.0
# 7       B00125OS3C    [0, 0]      5.0
# 8       B002IGHX40    [1, 1]      2.0
# 9       B004WPCQKG    [6, 7]      1.0
# 10      B000GAYQTU    [0, 0]      1.0
# 11      B002HHZVNA    [0, 1]      1.0
# 12      0957544901    [0, 0]      4.0
# 13      B002Y2U8MC    [1, 1]      5.0
# 14      B004P598FY    [1, 1]      5.0
# 15      B005MU3UE6    [1, 1]      5.0
# 16      0786903945    [0, 0]      5.0
# 17      B00474A3DY    [0, 0]      4.0
# 18      B00D8W4YO0    [2, 3]      5.0
# 19      1492111619    [0, 0]      5.0
# 20      B00EG0C20G    [1, 1]      5.0
# 21      0062023144    [0, 0]      5.0
# 22      076278038X    [0, 0]      4.0
# ...

# %%
## Convert data into Dataframe
data = pd.DataFrame([index for index in amazond_data])

# %%
def save_to_csv(save_name, data):
    data.to_csv(save_name, sep=',', encoding='utf-8')

# %%
save_to_csv('Amazon.csv', data)

# %% [markdown]
# #### Preprocessing the text data

# %%
# Tokenize Sentences and Words
token_sent = []
num_sent = []
token_word = []
num_word = []
for comment in df['reviewText']:
    sentence = sent_tokenize(comment)
    token_sent.append(sentence)
    num_sent.append(len(sentence))
    word = word_tokenize(comment)
    token_word.append(word)
    num_word.append(word)

# %%
# Create a new Dataframe to store them
new_df = pd.DataFrame(df[['asin', 'helpful', 'overall', 'reviewText']])
new_df['Tokenize Sentences'] = token_sent
new_df['Number of Sentences'] = num_sent
new_df['Tokenize Words'] = token_word
new_df['Number of Sentences'] = num_word

# %%
stops=set(stopwords.words('english'))
tokenized_string_no_punctuation = []
for review in df['reviewText']:
    tokenized_word = word_tokenize(review)
    # Remove all the stop words
    remove_stop_word = [word for word in tokenized_word if word not in stops]
